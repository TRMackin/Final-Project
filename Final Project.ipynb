# %%
import pygame
import time
import random
pygame.init()

black = (0, 0, 0)
red = (255, 0, 0)
green = (0, 255, 0)

display_width = 700
display_height = 500
 
display = pygame.display.set_mode((display_width, display_height))
pygame.display.set_caption("Snake")
 
clock = pygame.time.Clock()
 
snake_block = 10
snake_speed = 15
 
font_style = pygame.font.SysFont("freesansbold.ttf", 25)
score_font = pygame.font.SysFont("freesansbold.ttf", 35)

class player():
    def __init__(self, first, last):
        self.first = first.title()
        self.last = last.title()
        
    def fullname(self):
        return (f"{self.first} {self.last}")
        
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
player1 = player(first_name, last_name)

def Game_score(score):
    value = score_font.render(player1.fullname() + ", your score is: " + str(score), True, green)
    display.blit(value, [300, 475])
    
def snake(snake_block, snake_body):
    for x in snake_body:
        pygame.draw.rect(display, black, [x[0], x[1], snake_block, snake_block])
        
def lose_message(msg, color):
    message = font_style.render(msg, True, color)
    display.blit(message, [70, 225])
    
def snake_loop():
    game_over = False
    game_close = False
 
    x1 = display_width / 2
    y1 = display_height / 2
 
    x1_change = 0
    y1_change = 0
 
    snake_body = []
    snake_length = 1
 
    foodx = round(random.randrange(0, display_width - snake_block) / 10.0) * 10.0
    foody = round(random.randrange(0, display_height - snake_block) / 10.0) * 10.0
    
    while not game_over:
        while game_close == True:
            display.fill(red)
            Game_score(snake_length - 1)
            lose_message("YOU LOST! :( Try again? Press 'P' to play again or 'Q' to quit the game.", black)
            pygame.display.update()
            for event in pygame.event.get():
                if event.type == pygame.KEYDOWN:
                    if event.key == pygame.K_q:
                        game_over = True
                        game_close = False 
                    if event.key == pygame.K_p:
                        snake_loop()

        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                game_over = True
            if event.type == pygame.KEYDOWN:
                if event.key == pygame.K_LEFT:
                    x1_change = -snake_block
                    y1_change = 0
                    
                elif event.key == pygame.K_RIGHT:
                    x1_change = snake_block
                    y1_change = 0
                    
                elif event.key == pygame.K_UP:
                    y1_change = -snake_block
                    x1_change = 0
                    
                elif event.key == pygame.K_DOWN:
                    y1_change = snake_block
                    x1_change = 0
                    
                if event.key == pygame.K_a:
                    x1_change = -snake_block
                    y1_change = 0
                    
                elif event.key == pygame.K_d:
                    x1_change = snake_block
                    y1_change = 0
                    
                elif event.key == pygame.K_w:
                    y1_change = -snake_block
                    x1_change = 0
                    
                elif event.key == pygame.K_s:
                    y1_change = snake_block
                    x1_change = 0
                    
        if x1 >= display_width or x1 < 0 or y1 >= display_height or y1 < 0:
            game_close = True
        x1 += x1_change
        y1 += y1_change
        background = pygame.transform.scale(pygame.image.load("Snake background.jpg"), (display_width, display_height+100))
        display.blit(background, (0, 0))
        pygame.display.update()
        pygame.draw.rect(display, red, [foodx, foody, snake_block, snake_block])
        snake_Head = []
        snake_Head.append(x1)
        snake_Head.append(y1)
        snake_body.append(snake_Head)
        if len(snake_body) > snake_length:
            del snake_body[0]
            
        for x in snake_body[:-1]:
            if x == snake_Head:
                game_close = True
                
        snake(snake_block, snake_body)
        Game_score(snake_length - 1)
        pygame.display.update()
        
        if x1 == foodx and y1 == foody:
            foodx = round(random.randrange(0, display_width - snake_block) / 10.0) * 10.0
            foody = round(random.randrange(0, display_height - snake_block) / 10.0) * 10.0
            snake_length += 1
            
        clock.tick(snake_speed)
        
    pygame.quit()
        
    quit()
    
snake_loop()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Enter your first name: Thomas
# Enter your last name: Mackin
# 1   HIToolbox                           0x00007ff8155f5726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff8155f52b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff815599908 SetMenuBarObscured + 408
# 4   HIToolbox                           0x00007ff8155994ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 5   HIToolbox                           0x00007ff815593996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 6   HIToolbox                           0x00007ff81555bbd2 _NotifyEventLoopObservers + 153
# 7   HIToolbox                           0x00007ff8155933e6 AcquireEventFromQueue + 494
# ...
